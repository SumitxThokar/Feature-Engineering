# %% [markdown]
# # Working on Zomato Dataset

# %% [markdown]
# - Exploratory Data Analysis

# %%
# Importing basic libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Importing the zomato dataset.
data = pd.read_csv('zomato.csv',encoding='latin-1')

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.shape
# Out:
# (9551, 21)

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # Process:
#     - Missing Values and Imputation.
#     - Outlier Detection.
#     - Exploration - Numerical variable, Categorial Variable.
#     - Find Relationships.
#     - Transformatoin and Scaling.

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data_c = pd.read_excel('Country-code.xlsx')
data_c.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
data_c.shape
# Out:
# (15, 2)

# %%
final = pd.merge(data,data_c,on='Country Code',how='left')

# %%
final.sample(5)
# Out:
#       Restaurant ID          Restaurant Name  Country Code       City  \
# 8819            501                  Barista             1      Noida
# 5489         306250             Kebab Xpress             1  New Delhi
# 7138       18423865  Bikaner Sweets & Bakers             1  New Delhi
# 6025         302155  Madan Cafe & Restaurant             1  New Delhi
# 9083           8888         Ristorante Prego             1      Noida
#
#                                                 Address  \
# 8819          EXL Tower, 5, A-94/4, 5, Sector 58, Noida
# 5489  2nd Floor, Del15 Food Court, Moments Mall, Kir...
# 7138  Shop A1/1, West Jyoti Nagar, Durgapuri Chowk, ...
# 6025            1601, Main Bazaar, Paharganj, New Delhi
# 9083  323, 3rd Floor, The Great India Place Mall, Se...
#
#                               Locality  \
# 8819                         Sector 58
# 5489         Moments Mall, Kirti Nagar
# 7138                          Shahdara
# 6025                         Paharganj
# ...

# %%
country_names = final.Country.value_counts().index

# %%
country_num = final.Country.value_counts().values

# %%
# Top 3 country using zomato
plt.figure(figsize=(14,7))
plt.pie(country_num[:3],labels=country_names[:3]
       ,autopct="%1.1f%%",shadow=True,colors=["brown","grey","w"])
plt.legend(loc='upper right')
plt.title('Countries using Zomato')
plt.show()

# %% [markdown]
# We see that number of transactions in India is significantly higher than that of in UK, US and other countries.

# %%
num_ratings = final.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Count'})

# %%
num_ratings
# Out:
#     Aggregate rating Rating color Rating text  Count
# 0                0.0        White   Not rated   2148
# 1                1.8          Red        Poor      1
# 2                1.9          Red        Poor      2
# 3                2.0          Red        Poor      7
# 4                2.1          Red        Poor     15
# 5                2.2          Red        Poor     27
# 6                2.3          Red        Poor     47
# 7                2.4          Red        Poor     87
# 8                2.5       Orange     Average    110
# 9                2.6       Orange     Average    191
# 10               2.7       Orange     Average    250
# 11               2.8       Orange     Average    315
# 12               2.9       Orange     Average    381
# 13               3.0       Orange     Average    468
# 14               3.1       Orange     Average    519
# 15               3.2       Orange     Average    522
# 16               3.3       Orange     Average    483
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Rating text",y="Count",data=num_ratings,palette=['grey','red','orange','yellow','lightgreen','forestgreen'])
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Aggregate rating",y="Count",data=num_ratings)
plt.show()

# %% [markdown]
# - Most of the people don't rate about the service.
# - If we exclude Not rated category, The graph almost follow Normal Distribution.

# %%
# Countries name that has given 0 ratings.
final[final['Aggregate rating']==0].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %%
# Find out which currency is used by which country?
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final.groupby(['Country','Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %%
# Which countries do have online deliveries options.
final[final['Has Online delivery']=='Yes']['Country'].value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %% [markdown]
# Online delivery option is only available in India and UAE.

# %%
cities_name=final['City'].value_counts().index

# %%
cities_num=final['City'].value_counts().values

# %%
plt.figure(figsize=(15,8))
plt.pie(cities_num[:4],labels=cities_name[:4],
       shadow=True,colors=["yellow","orange","lightgreen","forestgreen"])
plt.legend(loc='upper right')
plt.title('Cities using Zomato')
plt.show()

# %% [markdown]
# Most of the users are from New Delhi.

# %%
# Find the top 10 cuisines.
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final['Cuisines'].value_counts().head(10).reset_index().rename(columns={'index':'Cuisines','Cuisines':'count'})
# Out:
#                          Cuisines  count
# 0                    North Indian    936
# 1           North Indian, Chinese    511
# 2                         Chinese    354
# 3                       Fast Food    354
# 4           North Indian, Mughlai    334
# 5                            Cafe    299
# 6                          Bakery    218
# 7  North Indian, Mughlai, Chinese    197
# 8                Bakery, Desserts    170
# 9                     Street Food    149

# %% [markdown]
# North Indian Cuisines are the most popular in Zomato.
